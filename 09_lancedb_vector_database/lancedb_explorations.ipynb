# %% [markdown]
# ## LanceDB vector database

# %%
import lancedb

vector_db = lancedb.connect(uri = "vector_database")

vector_db
# Out:
# LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database')

# %%
vector_db.uri
# Out:
# 'c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'

# %% [markdown]
# ## Create a table

# %%
import json

with open("animals_text_embeddings.json") as file:
    data = json.loads(file.read())

data
# Out:
# [{'text': 'A small brown dog running.', 'vector': [0.12, 0.85, 0.33]},
#  {'text': 'A cat resting quietly on a sofa.', 'vector': [0.4, 0.91, 0.1]},
#  {'text': 'A large gray elephant drinking water.',
#   'vector': [0.88, 0.22, 0.55]},
#  {'text': 'A fast cheetah sprinting across the savannah.',
#   'vector': [0.95, 0.12, 0.72]},
#  {'text': 'A colorful parrot perched on a branch.',
#   'vector': [0.25, 0.66, 0.81]},
#  {'text': 'A frog sitting on a lily pad.', 'vector': [0.14, 0.44, 0.27]}]

# %%
vector_db.create_table("animals", exist_ok=True, data=data)
# Out:
# LanceTable(name='animals', version=1, _conn=LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'))

# %%
vector_db.table_names()
# Out:
# ['animals']

# %%
vector_db["animals"]
# Out:
# LanceTable(name='animals', version=1, _conn=LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'))

# %%
vector_db["animals"].head()
# Out:
# pyarrow.Table
# text: string
# vector: fixed_size_list<item: float>[3]
#   child 0, item: float
# ----
# text: [["A small brown dog running.","A cat resting quietly on a sofa.","A large gray elephant drinking water.","A fast cheetah sprinting across the savannah.","A colorful parrot perched on a branch."]]
# vector: [[[0.12,0.85,0.33],[0.4,0.91,0.1],[0.88,0.22,0.55],[0.95,0.12,0.72],[0.25,0.66,0.81]]]

# %%
vector_db["animals"].to_pandas()
# Out:
#                                             text              vector
# 0                     A small brown dog running.  [0.12, 0.85, 0.33]
# 1               A cat resting quietly on a sofa.    [0.4, 0.91, 0.1]
# 2          A large gray elephant drinking water.  [0.88, 0.22, 0.55]
# 3  A fast cheetah sprinting across the savannah.  [0.95, 0.12, 0.72]
# 4         A colorful parrot perched on a branch.  [0.25, 0.66, 0.81]
# 5                  A frog sitting on a lily pad.  [0.14, 0.44, 0.27]

# %%
more_data = [
    {"text": "A panda eating bamboo peacefully.", "vector": [0.51, 0.37, 0.82]},
    {"text": "A lion roaring loudly on a rock.", "vector": [0.93, 0.18, 0.41]},
]

vector_db["animals"].add(more_data)
# Out:
# AddResult(version=2)

# %%
vector_db["animals"].to_pandas()
# Out:
#                                             text              vector
# 0                     A small brown dog running.  [0.12, 0.85, 0.33]
# 1               A cat resting quietly on a sofa.    [0.4, 0.91, 0.1]
# 2          A large gray elephant drinking water.  [0.88, 0.22, 0.55]
# 3  A fast cheetah sprinting across the savannah.  [0.95, 0.12, 0.72]
# 4         A colorful parrot perched on a branch.  [0.25, 0.66, 0.81]
# 5                  A frog sitting on a lily pad.  [0.14, 0.44, 0.27]
# 6              A panda eating bamboo peacefully.  [0.51, 0.37, 0.82]
# 7               A lion roaring loudly on a rock.  [0.93, 0.18, 0.41]

# %% [markdown]
# ## Create an empty table and drop it

# %%
from lancedb.pydantic import LanceModel

class JokeSchema(LanceModel):
    joke: str
    rating: int

vector_db.create_table(name = "jokes", schema = JokeSchema)
# Out:
# LanceTable(name='jokes', version=1, _conn=LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'))

# %%
vector_db.create_table(name = "joke_throw_away_table", schema=JokeSchema)
# Out:
# LanceTable(name='joke_throw_away_table', version=1, _conn=LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'))

# %%
vector_db.table_names()
# Out:
# ['animals', 'joke_throw_away_table', 'jokes']

# %%
vector_db.drop_table("joke_throw_away_table")

# %%
vector_db.table_names()
# Out:
# ['animals', 'jokes']

# %% [markdown]
# ## vector search in lancedb
# search with ANN (Approximate Nearest Neighbour)
#
# - search with vector directly
# - search with natural text and it automatically calculates its embedding

# %%
vector_db["animals"].to_pandas()
# Out:
#                                             text              vector
# 0                     A small brown dog running.  [0.12, 0.85, 0.33]
# 1               A cat resting quietly on a sofa.    [0.4, 0.91, 0.1]
# 2          A large gray elephant drinking water.  [0.88, 0.22, 0.55]
# 3  A fast cheetah sprinting across the savannah.  [0.95, 0.12, 0.72]
# 4         A colorful parrot perched on a branch.  [0.25, 0.66, 0.81]
# 5                  A frog sitting on a lily pad.  [0.14, 0.44, 0.27]
# 6              A panda eating bamboo peacefully.  [0.51, 0.37, 0.82]
# 7               A lion roaring loudly on a rock.  [0.93, 0.18, 0.41]

# %%
query_vector = [.8, .2, .6]

vector_db["animals"].search(query_vector).limit(5).to_pandas()
# Out:
#                                             text              vector  \
# 0          A large gray elephant drinking water.  [0.88, 0.22, 0.55]
# 1  A fast cheetah sprinting across the savannah.  [0.95, 0.12, 0.72]
# 2               A lion roaring loudly on a rock.  [0.93, 0.18, 0.41]
# 3              A panda eating bamboo peacefully.  [0.51, 0.37, 0.82]
# 4         A colorful parrot perched on a branch.  [0.25, 0.66, 0.81]
#
#    _distance
# 0     0.0093
# 1     0.0433
# 2     0.0534
# 3     0.1614
# 4     0.5582

# %%
try:
    vector_db["animals"].search("pandas eat bamboo").limit(3).to_pandas()
except RuntimeError as err:
    print(err)
# Out:
# lance error: Invalid user input: Cannot perform full text search unless an INVERTED index has been created on at least one column, C:\Users\runneradmin\.cargo\registry\src\index.crates.io-1949cf8c6b5b557f\lance-index-0.39.0\src\scalar\inverted\query.rs:703:25

# %% [markdown]
# ## Embeddings model

# %%
from lancedb.embeddings import get_registry
import numpy as np

embedding_model = get_registry().get("gemini-text").create(name = "gemini-embedding-001")
test_embedding = np.array(embedding_model.compute_query_embeddings("hej på dig"))
test_embedding # based on this, we know that the model embedds vectors with dim 3072
# Out:
# array([[-0.03153099,  0.00111794, -0.00046516, ..., -0.00987874,
#         -0.01296163, -0.0097622 ]], shape=(1, 3072))

# %%
vector_db.drop_table("jokes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 vector_db.drop_table("jokes")
#
# File c:\Users\Katrin\Documents\github\ai_engineering_katrin_rylander_de24\.venv\Lib\site-packages\lancedb\db.py:774, in LanceDBConnection.drop_table(self, name, namespace, ignore_missing)
#     756 @override
#     757 def drop_table(
#     758     self,
#    (...)    761     ignore_missing: bool = False,
#     762 ):
#     763     """Drop a table from the database.
#     764
#     765     Parameters
#    (...)    772         If True, ignore if the table does not exist.
#     773     """
# --> 774     LOOP.run(
#     775         self._conn.drop_table(
#     776             name, namespace=namespace, ignore_missing=ignore_missing
#     777         )
#     778     )
#
# File c:\Users\Katrin\Documents\github\ai_engineering_katrin_rylander_de24\.venv\Lib\site-packages\lancedb\background_loop.py:25, in BackgroundEventLoop.run(self, future)
#      24 def run(self, future):
# ---> 25     return asyncio.run_coroutine_threadsafe(future, self.loop).result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.1-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Katrin\Documents\github\ai_engineering_katrin_rylander_de24\.venv\Lib\site-packages\lancedb\db.py:1331, in AsyncConnection.drop_table(self, name, namespace, ignore_missing)
#    1329 except ValueError as e:
#    1330     if not ignore_missing:
# -> 1331         raise e
#    1332     if f"Table '{name}' was not found" not in str(e):
#    1333         raise e
#
# File c:\Users\Katrin\Documents\github\ai_engineering_katrin_rylander_de24\.venv\Lib\site-packages\lancedb\db.py:1328, in AsyncConnection.drop_table(self, name, namespace, ignore_missing)
#    1315 """Drop a table from the database.
#    1316
#    1317 Parameters
#    (...)   1325     If True, ignore if the table does not exist.
#    1326 """
#    1327 try:
# -> 1328     await self._inner.drop_table(name, namespace=namespace)
#    1329 except ValueError as e:
#    1330     if not ignore_missing:
#
# ValueError: Table 'jokes' was not found

# %%
vector_db.table_names()
# Out:
# ['animals']

# %%
from lancedb.pydantic import LanceModel, Vector

class JokeModel(LanceModel):
    joke: str = embedding_model.SourceField() # joke becomes our source column
    vector: Vector(3072) = embedding_model.VectorField() # target vector column

vector_db.create_table("jokes", schema=JokeModel,exist_ok=True)
vector_db["jokes"]
# Out:
# LanceTable(name='jokes', version=1, _conn=LanceDBConnection(uri='c:\\Users\\Katrin\\Documents\\github\\ai_engineering_katrin_rylander_de24\\09_lancedb_vector_database\\vector_database'))

# %%
import pandas as pd

with open("jokes.json", encoding="utf-8") as file:
    jokes_data = json.loads(file.read())

df_jokes = pd.DataFrame(jokes_data).rename({"jokes":"joke"}, axis=1)
df_jokes.head()
# Out:
#                                                 joke
# 0  Parallel lines have so much in common—it’s sad...
# 1  ETL stands for “Extract, Transform, Leave for ...
# 2  What do you call a snake that runs your script...
# 3  Gold walks into a bar. The bartender says, “Au...
# 4   C# devs don’t argue; they just throw exceptions.

# %%
vector_db["jokes"].add(df_jokes)
# Out:
# AddResult(version=2)

# %%
vector_db["jokes"].to_pandas().head()
# Out:
#                                                 joke  \
# 0  Parallel lines have so much in common—it’s sad...
# 1  ETL stands for “Extract, Transform, Leave for ...
# 2  What do you call a snake that runs your script...
# 3  Gold walks into a bar. The bartender says, “Au...
# 4   C# devs don’t argue; they just throw exceptions.
#
#                                               vector
# 0  [-0.024001757, 0.01247358, -0.024144737, -0.06...
# 1  [-0.015356114, 0.0211365, -0.021389864, -0.079...
# 2  [-0.01761013, 0.0031474787, -0.015632002, -0.0...
# 3  [-0.024867292, 0.013314825, -0.016261652, -0.0...
# 4  [-0.0068662865, -0.005415149, 0.0044965413, -0...

# %%
vector_db["jokes"].to_pandas().iloc[0]["vector"]
# Out:
# array([-0.02400176,  0.01247358, -0.02414474, ...,  0.01160614,
#         0.00044886,  0.01217596], shape=(3072,), dtype=float32)

# %%
vector_db["jokes"].search("tell me a few chemistry jokes").limit(5).to_pandas()
# Out:
#                                                 joke  \
# 0    I told a chemistry joke… there was no reaction.
# 1  Why did the chemist ground his kids? Because t...
# 2  Gold walks into a bar. The bartender says, “Au...
# 3  Chemists have all the solutions… mostly in bea...
# 4             Oxygen and Magnesium got together—OMg!
#
#                                               vector  _distance
# 0  [-0.022922393, 0.017959604, -0.029222224, -0.0...   0.589529
# 1  [-0.023257235, 0.016145445, -0.029016329, -0.0...   0.639561
# 2  [-0.024867292, 0.013314825, -0.016261652, -0.0...   0.696513
# 3  [-0.012411982, -0.002532549, -0.0061755716, -0...   0.698228
# 4  [-0.024720555, 0.006975079, -0.015012385, -0.0...   0.782264

# %%
vector_db["jokes"].search("see sharp").limit(5).to_pandas()
# Out:
#                                                 joke  \
# 0  Why is C# like a musical? It has so many classes.
# 1   C# devs don’t argue; they just throw exceptions.
# 2  The C# compiler walked into a bar. The bartend...
# 3  Why did the C# developer go broke? He kept usi...
# 4  I tried to explain async/await to my friend… n...
#
#                                               vector  _distance
# 0  [-0.012926053, 0.0034431089, -0.017093537, -0....   0.745630
# 1  [-0.0068662865, -0.005415149, 0.0044965413, -0...   0.809269
# 2  [-0.01868987, 0.018796643, -0.009748903, -0.07...   0.813187
# 3  [-0.02175711, 0.0073709465, -0.015515881, -0.0...   0.816001
# 4  [-0.016174542, 0.012602222, -0.015254588, -0.0...   0.824324
